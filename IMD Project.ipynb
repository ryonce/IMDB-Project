# %% [markdown]
# # IMD Project

# %% [markdown]
# ## Imports and Data

# %%
import pandas as pd
import numpy as np

# %%
# Basics

basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                    primaryTitle  \
# 0  tt0000009     movie                      Miss Jerry
# 1  tt0000574     movie     The Story of the Kelly Gang
# 2  tt0000591     movie                The Prodigal Son
# 3  tt0000679     movie  The Fairylogue and Radio-Plays
# 4  tt0001285     movie               The Life of Moses
#
#                     originalTitle  isAdult  startYear  endYear  \
# 0                      Miss Jerry        0       1894      NaN
# 1     The Story of the Kelly Gang        0       1906      NaN
# 2               L'enfant prodigue        0       1907      NaN
# 3  The Fairylogue and Radio-Plays        0       1908      NaN
# 4               The Life of Moses        0       1909      NaN
#
#    runtimeMinutes                      genres
# 0              45                     Romance
# 1              70  Action,Adventure,Biography
# 2              90                       Drama
# 3             120           Adventure,Fantasy
# 4              50      Biography,Drama,Family

# %%
# Basics

# basics = pd.read_csv('https://datasets.imdbws.com/title.basics.tsv.gz', sep='\t', low_memory=False)
# basics.head()

# %%
# Ratings


ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1965
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1808
# 3  tt0000004            5.6       178
# 4  tt0000005            6.2      2607

# %%
# Ratings

# ratings = pd.read_csv('https://datasets.imdbws.com/title.ratings.tsv.gz', sep='\t', low_memory=False)
# ratings.head()

# %%
# Akas

akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
# Akas

# akas = pd.read_csv('https://datasets.imdbws.com/title.akas.tsv.gz', sep='\t', low_memory=False)
# akas.head()

# %% [markdown]
# ## Filtering Data - Missing Values

# %%
# Replace \N values

basics = basics.replace({'\\N':np.nan})
ratings = ratings.replace({'\\N':np.nan})
akas = akas.replace({'\\N':np.nan})

# %%
# Exclude any movie with missing values for genre or runtime

print(f'There are {basics.isna().sum().sum()} missing values.')

print(basics.isna().sum())
# Out:
# There are 158200 missing values.
# tconst                 0
# titleType              0
# primaryTitle           0
# originalTitle          0
# isAdult                0
# startYear              0
# endYear           158200
# runtimeMinutes         0
# genres                 0
# dtype: int64

# %%
# Drop genres

basics.dropna(subset = 'genres', inplace = True)

# %%
# Drop runtimeMinutes

basics.dropna(subset = 'runtimeMinutes', inplace = True)

# %%
# Check values again

print(f'There are {basics.isna().sum().sum()} missing values.')

print(basics.isna().sum())
# Out:
# There are 158200 missing values.
# tconst                 0
# titleType              0
# primaryTitle           0
# originalTitle          0
# isAdult                0
# startYear              0
# endYear           158200
# runtimeMinutes         0
# genres                 0
# dtype: int64

# %% [markdown]
# ## Filtering Data - Movie

# %%
# Include only full-length movies (titleType = "movie").

movie = basics['titleType'] == 'movie'
basics = basics[movie]
basics.head()
# Out:
#       tconst titleType                    primaryTitle  \
# 0  tt0000009     movie                      Miss Jerry
# 1  tt0000574     movie     The Story of the Kelly Gang
# 2  tt0000591     movie                The Prodigal Son
# 3  tt0000679     movie  The Fairylogue and Radio-Plays
# 4  tt0001285     movie               The Life of Moses
#
#                     originalTitle  isAdult  startYear  endYear  \
# 0                      Miss Jerry        0       1894      NaN
# 1     The Story of the Kelly Gang        0       1906      NaN
# 2               L'enfant prodigue        0       1907      NaN
# 3  The Fairylogue and Radio-Plays        0       1908      NaN
# 4               The Life of Moses        0       1909      NaN
#
#    runtimeMinutes                      genres
# 0              45                     Romance
# 1              70  Action,Adventure,Biography
# 2              90                       Drama
# 3             120           Adventure,Fantasy
# 4              50      Biography,Drama,Family

# %% [markdown]
# ## Filtering Data - Documentary

# %%
# Include only fictional movies (not from documentary genre)

is_documentary = basics['genres'].str.contains('documentary', case=False)
basics = basics[~is_documentary]
basics.head()
# Out:
#       tconst titleType                    primaryTitle  \
# 0  tt0000009     movie                      Miss Jerry
# 1  tt0000574     movie     The Story of the Kelly Gang
# 2  tt0000591     movie                The Prodigal Son
# 3  tt0000679     movie  The Fairylogue and Radio-Plays
# 4  tt0001285     movie               The Life of Moses
#
#                     originalTitle  isAdult  startYear  endYear  \
# 0                      Miss Jerry        0       1894      NaN
# 1     The Story of the Kelly Gang        0       1906      NaN
# 2               L'enfant prodigue        0       1907      NaN
# 3  The Fairylogue and Radio-Plays        0       1908      NaN
# 4               The Life of Moses        0       1909      NaN
#
#    runtimeMinutes                      genres
# 0              45                     Romance
# 1              70  Action,Adventure,Biography
# 2              90                       Drama
# 3             120           Adventure,Fantasy
# 4              50      Biography,Drama,Family

# %% [markdown]
# ## Filtering Data - StartYear 2000-2022

# %%
basics['startYear'].astype('int')
years = basics['startYear'] >= 2000
basics = basics[years]
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 16161  tt0035423     movie                                     Kate & Leopold
# 28601  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 31485  tt0069049     movie                         The Other Side of the Wind
# 38424  tt0088751     movie                                  The Naked Monster
# 41036  tt0096056     movie                               Crime and Punishment
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 16161                             Kate & Leopold        0       2001      NaN
# 28601  El tango del viudo y su espejo deformante        0       2020      NaN
# 31485                 The Other Side of the Wind        0       2018      NaN
# 38424                          The Naked Monster        0       2005      NaN
# 41036                       Crime and Punishment        0       2002      NaN
#
#        runtimeMinutes                  genres
# 16161             118  Comedy,Fantasy,Romance
# 28601              70                   Drama
# 31485             122                   Drama
# 38424             100    Comedy,Horror,Sci-Fi
# 41036             126                   Drama

# %% [markdown]
# ## Filtering Data - US Only

# %%
# Create filter in akas DF

usa = akas['region'] == 'US'
akas = akas[usa]
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe

keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 16161     True
# 28601     True
# 31485     True
# 38424     True
# 41036     True
#           ...
# 158195    True
# 158196    True
# 158197    True
# 158198    True
# 158199    True
# Name: tconst, Length: 88171, dtype: bool

# %%
# Created final DF

basics = basics[keepers]
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 16161  tt0035423     movie                                     Kate & Leopold
# 28601  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 31485  tt0069049     movie                         The Other Side of the Wind
# 38424  tt0088751     movie                                  The Naked Monster
# 41036  tt0096056     movie                               Crime and Punishment
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 16161                             Kate & Leopold        0       2001      NaN
# 28601  El tango del viudo y su espejo deformante        0       2020      NaN
# 31485                 The Other Side of the Wind        0       2018      NaN
# 38424                          The Naked Monster        0       2005      NaN
# 41036                       Crime and Punishment        0       2002      NaN
#
#        runtimeMinutes                  genres
# 16161             118  Comedy,Fantasy,Romance
# 28601              70                   Drama
# 31485             122                   Drama
# 38424             100    Comedy,Horror,Sci-Fi
# 41036             126                   Drama

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe

keepers2 = ratings['tconst'].isin(akas['titleId'])
keepers2
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1305608    False
# 1305609    False
# 1305610    False
# 1305611    False
# 1305612    False
# Name: tconst, Length: 1305613, dtype: bool

# %%
# Created final DF

ratings = ratings[keepers2]
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1965
# 1  tt0000002            5.8       263
# 4  tt0000005            6.2      2607
# 5  tt0000006            5.2       181
# 6  tt0000007            5.4       816

# %% [markdown]
# ## Creating New Folder & Files

# %%
# example making new folder with os

import os

os.makedirs('Data/',exist_ok=True)

# Confirm folder created

os.listdir("Data/")
# Out:
# ['title_basics.csv.gz', 'title_akas.csv.gz', 'title_ratings.csv.gz']

# %%
# Save current dataframe to file.

basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)
